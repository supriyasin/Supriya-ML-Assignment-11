# %%
#1. Given X be a discrete random variable with the following PMF
Px(x) = 0.1 for x = 0.2                                                
        0.2 for x = 0.4                                         
        0.2 for x = 0.5                 
        0.3 for x = 0.8               
        0.2 for x = 1                      
        0 otherwise                                                                                                                       
1. Find the range RX of the random variable X.
2. Find P(X ≤ 0.5)
3. Find P(0.25&lt;X&lt;0.75)
4. P(X = 0.2|X&lt;0.6)               

"""Great, now that we have the PMF for the random variable X, let's proceed with the calculations:

   1.Range RX of the random variable X:
     The range of a random variable is the set of all possible values that the variable can take. From the given 
     PMF, the possible values of X are 0.2, 0.4, 0.5, 0.8, and 1. Therefore, the range RX of the random variable 
     X is {0.2, 0.4, 0.5, 0.8, 1}.

   2. P(X ≤ 0.5):
      To find this probability, we sum up the probabilities of all values of X that are less than or equal to 0.5.
      P(X ≤ 0.5) = P(X = 0.2) + P(X = 0.4) + P(X = 0.5)
                 = 0.1 + 0.2 + 0.2
                 = 0.5

   3. P(0.25 < X < 0.75):
      To find this probability, we sum up the probabilities of all values of X that fall within the range (0.25, 0.75).
      P(0.25 < X < 0.75) = P(X = 0.4) + P(X = 0.5)
                         = 0.2 + 0.2
                         = 0.4

   4. P(X = 0.2|X < 0.6):
      This is a conditional probability. To calculate it, we need to find the probability of X being 0.2 given that
      X is less than 0.6.
      P(X = 0.2|X < 0.6) = P(X = 0.2 and X < 0.6) / P(X < 0.6)

      First, let's find P(X = 0.2 and X < 0.6):
      P(X = 0.2 and X < 0.6) = P(X = 0.2) = 0.1

      Now, let's find P(X < 0.6):
      P(X < 0.6) = P(X = 0.2) + P(X = 0.4) + P(X = 0.5)
                 = 0.1 + 0.2 + 0.2
                 = 0.5

     Now, plug these values into the conditional probability formula:
     P(X = 0.2|X < 0.6) = (P(X = 0.2 and X < 0.6)) / P(X < 0.6)
                        = 0.1 / 0.5
                        = 0.2

     So, P(X = 0.2|X < 0.6) is 0.2."""

#2. Two equal and fair dice are rolled, and we observed two numbers X and Y.
1. Find RX, RY, and the PMFs of X and Y.
2. Find P(X = 2,Y = 6).
3. Find P(X&gt;3|Y = 2).
4. If Z = X + Y. Find the range and PMF of Z.
5. Find P(X = 4|Z = 8).

"""Sure, let's go through the questions step by step:

   Given:
   - Two equal and fair dice are rolled.
   - We observe two numbers X and Y.

   1. Find RX, RY, and the PMFs of X and Y:
      For each die roll, there are six possible outcomes (1, 2, 3, 4, 5, 6). Since we're observing the outcomes of
      two dice rolls for X and Y, the possible values for both X and Y range from 1 to 6.
   
      So, RX = RY = {1, 2, 3, 4, 5, 6}.
   
      Since the dice are fair, the PMFs of X and Y are uniform, meaning each outcome has an equal probability of 1/6.
   
      PMF of X: P(X = x) = 1/6 for x ∈ {1, 2, 3, 4, 5, 6}
      PMF of Y: P(Y = y) = 1/6 for y ∈ {1, 2, 3, 4, 5, 6}

   2. Find P(X = 2, Y = 6):
      The probability of X being 2 and Y being 6 is the product of the probabilities of these independent events:
   
      P(X = 2, Y = 6) = P(X = 2) * P(Y = 6) = (1/6) * (1/6) = 1/36

   3. Find P(X > 3 | Y = 2):
      If we know that Y is 2, then X cannot be greater than 3, as each die has values from 1 to 6.
   
      P(X > 3 | Y = 2) = 0

   4. If Z = X + Y, Find the range and PMF of Z:
      The possible values of Z range from 2 (1 + 1) to 12 (6 + 6).
   
      The PMF of Z can be calculated by considering all possible pairs of values (x, y) that sum to each value 
      of Z and multiplying their individual probabilities. Since the dice are fair, the probabilities of each 
      outcome are 1/6.
   
      PMF of Z: P(Z = z) = ∑ P(X = x, Y = z - x) for x ∈ {1, 2, ..., 6} where z ∈ {2, 3, ..., 12}

   5. Find P(X = 4 | Z = 8):
      To find the conditional probability P(X = 4 | Z = 8), you would need to calculate the probability that 
      X is 4 given that Z (the sum of X and Y) is 8. This involves summing up the probabilities of all pairs
      (x, y) where x = 4 and x + y = 8. These pairs are (4, 4) and (4, 5).
   
      P(X = 4 | Z = 8) = P(X = 4, Y = 4) + P(X = 4, Y = 5)

     Remember that for conditional probabilities, you need to divide by the probability of the given condition
     (in this case, P(Z = 8)).

     Please let me know if you would like me to perform any specific calculations or provide further explanations
     on any of the points above."""

#3. In an exam, there were 20 multiple-choice questions. Each question had 44 possible
options. A student knew the answer to 10 questions, but the other 10 questions were unknown
to him, and he chose answers randomly. If the student X's score is equal to the total number
of correct answers, then find out the PMF of X. What is P(X&gt;15)?

"""In this scenario, the student's score, denoted as X, is the total number of correct answers out of the 
   20 questions. Let's break down the calculation step by step.

   1. Calculate the PMF of X:

      The student knows the answer to 10 questions and chooses randomly for the other 10. The PMF (Probability
      Mass Function) of X represents the probability of getting a specific score X. Since the student knows the
      answers to 10 questions, their score can be anywhere from 0 to 10, inclusive.

      For each value of X from 0 to 10, we need to calculate the probability of getting that score. Since the 
      student has a 50% chance of answering correctly for each unknown question, and we're dealing with independent 
      events, we can use the binomial distribution formula:

      PMF of X: P(X = x) = C(20, x) * (0.5)^x * (0.5)^(20 - x)

      Where C(n, k) represents the binomial coefficient "n choose k."

     Now let's calculate the PMF for each value of X:

     - P(X = 0) = C(20, 0) * (0.5)^0 * (0.5)^20 = (1) * (1) * (0.5)^20
     - P(X = 1) = C(20, 1) * (0.5)^1 * (0.5)^19
     - ...
     - P(X = 10) = C(20, 10) * (0.5)^10 * (0.5)^10

     Note that the binomial coefficient C(20, x) can be calculated as 20! / (x! * (20 - x)!).

  2. Calculate P(X > 15):

    To find P(X > 15), you would sum up the probabilities of getting scores from 16 to 20:

    P(X > 15) = P(X = 16) + P(X = 17) + ... + P(X = 20)

    Calculate each of these probabilities using the same formula as above.

    Keep in mind that these calculations can be quite involved due to the number of combinations, but they 
    follow a similar pattern. If you'd like, I can perform specific calculations for you. Just let me know 
    which probabilities you'd like to calculate, and I'll be happy to assist further."""

#4. The number of students arriving at a college between a time interval is a Poisson random
variable. On average, 10 students arrive per hour. Let Y be the number of students arriving
from 10 am to 11:30 am. What is P(10&lt;Y≤15)?
    
"""In this scenario, the number of students arriving at the college between a time interval follows a Poisson 
   distribution with an average arrival rate of 10 students per hour. The Poisson distribution is characterized 
   by a single parameter, which is the average rate of occurrence.

   Let's denote the number of students arriving from 10 am to 11:30 am as Y. Given that the average rate is 10 
   students per hour, we need to adjust it for the 1.5-hour time interval (from 10 am to 11:30 am) to get the
   average number of arrivals during that interval:

   Average number of arrivals in the interval = (Average rate per hour) * (Length of interval in hours)
                                              = 10 * 1.5
                                              = 15

   Now, we can use the Poisson distribution formula to calculate the probabilities:

   P(Y = y) = (e^(-λ) * λ^y) / y!

   Where:
   - λ is the average number of arrivals during the interval (15 in this case).
   - y is the number of arrivals for which we want to calculate the probability.
   - e is the base of the natural logarithm, approximately equal to 2.71828.

   For your question, you want to find P(10 < Y ≤ 15). This involves calculating the probabilities for Y = 11,
   Y = 12, Y = 13, Y = 14, and Y = 15, and then summing them up:

   P(10 < Y ≤ 15) = P(Y = 11) + P(Y = 12) + P(Y = 13) + P(Y = 14) + P(Y = 15)

   Calculate each of these probabilities using the Poisson distribution formula with λ = 15. Finally, sum up these
   probabilities to get the desired result.

   Please note that these calculations involve exponentials and factorials, which might be a bit complex to compute
   manually. You can use a calculator or a statistical software tool to perform these calculations easily. If you
   need further assistance or specific calculated values, feel free to ask."""

#5.Two independent random variables, X and Y,are given such that X~Poisson(α) and
Y~Poisson(β). State a new random variable as Z = X + Y. Find out the PMF of Z.

"""When two independent random variables, X and Y, both follow Poisson distributions with parameters α and β, 
   respectively, the sum of these random variables, Z = X + Y, also follows a Poisson distribution. 
   The parameter of the resulting Poisson distribution for Z is the sum of the parameters of X and Y, i.e., λ = α + β.

   The probability mass function (PMF) of a Poisson random variable Z is given by:

   P(Z = z) = (e^(-λ) * λ^z) / z!

   Where:
   - λ is the parameter of the Poisson distribution (in this case, λ = α + β).
   - z is the value for which we want to calculate the probability.
   - e is the base of the natural logarithm, approximately equal to 2.71828.

   So, the PMF of the new random variable Z = X + Y is:

   P(Z = z) = (e^(-λ) * λ^z) / z!

  We can use this formula to calculate the probability of Z taking a specific value z based on the given values of α and β.

  Keep in mind that this is the PMF for the sum of two independent Poisson random variables. If you're looking for
  the PMF of the sum of more than two variables or for more complex scenarios, the calculation might involve
  convolutions of distributions."""

# 6. There is a discrete random variable X with the pmf.             

If we define a new random variable Y = (X + 1)2 then

1. Find the range of Y.

2. Find the pmf of Y.

2.Assuming X is a continuous random variable with PDF

1. Find EX and Var(X).
2. Find P(X ≥ ).

2. If X is a continuous random variable with pdf 

3. If X~Uniform and Y = sin(X), then find f Y (y).
4. If X is a random variable with CDF 

1. What kind of random variable is X: discrete, continuous, or mixed?

2. Find the PDF of X, fX(x).
3. Find E(e X ).
4. Find P(X = 0|X≤0.5).

2. There are two random variables X and Y with joint PMF given in Table below

1. Find P(X≤2, Y≤4).
2. Find the marginal PMFs of X and Y.
3. Find P(Y = 2|X = 1).
4. Are X and Y independent? 

6.A box containing 40 white shirts and 60 black shirts. If we choose 10 shirts (without replacement)
at random, find the joint PMF of X and Y, where X is the number of white shirts and Y is the number
of black shirts.

"""It seems like we've provided multiple sets of questions involving various random variables and probability 
   distributions. To ensure clarity and organization, let's address each set of questions separately:

   Set 1: Transformation of Random Variable Y = (X + 1)^2

   1. Find the range of Y:
      The range of Y depends on the range of X. Since X is a random variable with a given PMF, you would need
      to examine its possible values to determine the range of Y.

   2. Find the PMF of Y:
      To find the PMF of Y, you need to transform the PMF of X using the formula Y = (X + 1)^2. The resulting
      PMF will provide the probabilities associated with each value of Y.

  Set 2: Continuous Random Variable X with PDF

  1. Find EX and Var(X):
     Calculate the expected value (mean) and variance of the continuous random variable X using the provided PDF.

  2. Find P(X ≥ a):
     Determine the probability that X is greater than or equal to a specific value a using the given PDF.

  3. Find the PDF of X, fX(x):
     The PDF of the continuous random variable X should be provided based on the given information.

  4. Find E(e^X):
     Calculate the expected value of the exponential of X, E(e^X), using the provided PDF.

  5. Find P(X = 0|X ≤ 0.5):
     Calculate the conditional probability that X equals 0 given that X is less than or equal to 0.5.

  Set 3: Joint PMF of Random Variables X and Y

  1. Find P(X ≤ 2, Y ≤ 4):
     Determine the joint probability that X is less than or equal to 2 and Y is less than or equal to 4.

  2. Find the marginal PMFs of X and Y:
     Calculate the marginal PMFs of X and Y by summing the joint probabilities over the respective variable.

  3. Find P(Y = 2|X = 1):
     Calculate the conditional probability that Y equals 2 given that X equals 1.

  4. Are X and Y independent?
     Assess the independence of X and Y based on their joint PMF and whether it can be factored into the product
     of their marginal PMFs.

  Set 4: Joint PMF of X and Y (Sampling Without Replacement)

  To find the joint PMF of X (number of white shirts) and Y (number of black shirts) when drawing 10 shirts
  from the box without replacement, you would need to consider the hypergeometric distribution. This distribution
  models sampling without replacement from a finite population.

  If we would like, I can help you with specific calculations, formulas, and explanations for any of the scenarios 
  above. Just let me know which specific questions you'd like to address."""

#7.If A and B are two jointly continuous random variables with joint PDF

a. Find fX(a) and fY(b).

b. Are A and B independent of each other?

c. Find the conditional PDF of A given B = b, fA|B(a|b).

d. Find E[A|B = b], for 0 ≤ y ≤ 1.

e. Find Var(A|B = b), for 0 ≤ y ≤ 1.

"""Certainly, let's address each part of the question step by step:

   Given:
   Joint PDF of random variables A and B: f(a, b)

   a. Find fX(a) and fY(b):
      To find the marginal PDFs of A (fX(a)) and B (fY(b)), you integrate the joint PDF over the appropriate
      variable while keeping the other variable constant.

      Marginal PDF of A (fX(a)) = ∫ f(a, b) db over the range of possible values for B.
      Marginal PDF of B (fY(b)) = ∫ f(a, b) da over the range of possible values for A.

  b. Are A and B independent of each other?
     A and B are independent if and only if their joint PDF can be factored into the product of their marginal 
     PDFs. If this condition is satisfied, then A and B are independent; otherwise, they are dependent.

  c. Find the conditional PDF of A given B = b, fA|B(a|b):
     The conditional PDF of A given B = b can be found using the joint PDF and the following formula:

     fA|B(a|b) = f(a, b) / fY(b), where fY(b) is the marginal PDF of B evaluated at b.

  d. Find E[A|B = b], for 0 ≤ y ≤ 1:
     The conditional expectation of A given B = b can be calculated using the conditional PDF:

     E[A|B = b] = ∫ a * fA|B(a|b) da over the range of possible values for A.

  e. Find Var(A|B = b), for 0 ≤ y ≤ 1:
     The conditional variance of A given B = b can be calculated using the conditional PDF and the formula for variance:

     Var(A|B = b) = E[(A - E[A|B = b])^2 | B = b]
                  = ∫ (a - E[A|B = b])^2 * fA|B(a|b) da over the range of possible values for A.

  Please note that the specific calculations will depend on the form of the joint PDF f(a, b) and the range of
  possible values for A and B. If you have the actual joint PDF or more information, I can assist you with performing
  the calculations."""

#8.There are 100 men on a ship. If Xi is the ith man&#39;s weight on the ship and Xi&#39;s are independent and
identically distributed and EXi = μ = 170 and σXi = σ = 30. Find the probability that the men's total
weight on the ship exceeds 18,000.

"""Given that the weights of the men on the ship, Xi, are independent and identically distributed with a mean
   (expected value) of μ = 170 and a standard deviation of σ = 30, you can model their total weight as a sum 
   of these individual weights.

   Let's denote the total weight of the 100 men as W = X1 + X2 + ... + X100.

   The mean of the total weight is given by E[W] = E[X1] + E[X2] + ... + E[X100] = 100 * μ.

   The variance of the total weight is given by Var(W) = Var(X1) + Var(X2) + ... + Var(X100) = 100 * σ^2.

   The standard deviation of the total weight is then σW = √Var(W).

   Given the information provided, the mean and standard deviation of the total weight are:
   E[W] = 100 * μ = 100 * 170 = 17000
   σW = √(100 * σ^2) = √(100 * 900) = 300

  Now, you want to find the probability that the men's total weight exceeds 18,000. This can be formulated as a Z-score:

  Z = (W - E[W]) / σW
    = (18000 - 17000) / 300
    = 1/3

  Using a standard normal distribution table or a calculator, you can find the probability that Z is greater
  than 1/3. This will give you the probability that the men's total weight exceeds 18,000.

  Alternatively, you can use a cumulative distribution function (CDF) calculator for the normal distribution 
  with mean 0 and standard deviation 1 to find P(Z > 1/3).

  Keep in mind that these calculations involve standard normal distribution values. If you have access to a
  statistical software tool or calculator, you can easily compute this probability."""

#9.Let X1, X2, ……, X25 are independent and identically distributed. And have the following PMF

If Y = X1 + X2 + … + Xn, estimate P(4 ≤ Y ≤ 6) using central limit theorem.

"""The central limit theorem states that the distribution of the sum (or average) of a large number of 
   independent, identically distributed random variables approaches a normal distribution, regardless of 
   the original distribution of the individual variables, as long as certain conditions are met.

   In your case, you have 25 independent and identically distributed random variables, X1, X2, ..., X25,
   each with a given PMF.

   To estimate P(4 ≤ Y ≤ 6), where Y = X1 + X2 + ... + X25, you can use the central limit theorem. First, 
   calculate the mean (μ_Y) and the standard deviation (σ_Y) of the sum Y:

   μ_Y = n * μ_X, where n is the number of variables (25 in this case), and μ_X is the mean of a single X variable.
   σ_Y = √(n * σ_X^2), where σ_X is the standard deviation of a single X variable.

   Then, you can transform the interval [4, 6] to a standardized interval in terms of Z-scores:

   Z_4 = (4 - μ_Y) / σ_Y
   Z_6 = (6 - μ_Y) / σ_Y

   Using the standard normal distribution table or a calculator, you can find the probabilities P(Z_4 ≤ Z ≤ Z_6),
   where Z is a standard normal random variable.

   Keep in mind that the central limit theorem works better when the sample size is large. With 25 variables, you 
   should get a reasonable approximation of the probability using this approach. However, the accuracy of the 
   estimate will depend on how well the conditions for the central limit theorem are met and the shape of the 
   original PMF.

   If you have access to a statistical software tool or calculator, you can perform these calculations easily."""
